# %% [markdown]
# # This is just a test
#
# This is a simple Jupyter Notebook to check if you have access to Colab. Run the file and contact us in case you encounter a problem.

# %%
import numpy as np

a = np.array([1, 2, 3])

print(f' Congrats, this is your Numpy array: {a}')
